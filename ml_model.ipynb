# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pickle
from sklearn.linear_model import LogisticRegression

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %matplotlib inline
import seaborn as sns

# %%
all_data=pd.read_csv('heart.csv')
all_data.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  ...  exng  oldpeak  slp  caa  thall  output
# 0   63    1   3     145   233    1  ...     0      2.3    0    0      1       1
# 1   37    1   2     130   250    0  ...     0      3.5    0    0      2       1
# 2   41    0   1     130   204    0  ...     0      1.4    2    0      2       1
# 3   56    1   1     120   236    0  ...     0      0.8    2    0      2       1
# 4   57    0   0     120   354    0  ...     1      0.6    2    0      2       1
#
# [5 rows x 14 columns]

# %%
all_data.tail()
# Out:
#      age  sex  cp  trtbps  chol  fbs  ...  exng  oldpeak  slp  caa  thall  output
# 298   57    0   0     140   241    0  ...     1      0.2    1    0      3       0
# 299   45    1   3     110   264    0  ...     0      1.2    1    0      3       0
# 300   68    1   0     144   193    1  ...     0      3.4    1    2      3       0
# 301   57    1   0     130   131    0  ...     1      1.2    1    1      3       0
# 302   57    0   1     130   236    0  ...     0      0.0    1    1      2       0
#
# [5 rows x 14 columns]

# %%
x=all_data.drop(columns='output')
y=all_data['output']

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: output, dtype: int64

# %%
x.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  ...  thalachh  exng  oldpeak  slp  caa  thall
# 0   63    1   3     145   233    1  ...       150     0      2.3    0    0      1
# 1   37    1   2     130   250    0  ...       187     0      3.5    0    0      2
# 2   41    0   1     130   204    0  ...       172     0      1.4    2    0      2
# 3   56    1   1     120   236    0  ...       178     0      0.8    2    0      2
# 4   57    0   0     120   354    0  ...       163     1      0.6    2    0      2
#
# [5 rows x 13 columns]

# %%
x=x.drop(columns='time')

# %%
x.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  ...  thalachh  exng  oldpeak  slp  caa  thall
# 0   63    1   3     145   233    1  ...       150     0      2.3    0    0      1
# 1   37    1   2     130   250    0  ...       187     0      3.5    0    0      2
# 2   41    0   1     130   204    0  ...       172     0      1.4    2    0      2
# 3   56    1   1     120   236    0  ...       178     0      0.8    2    0      2
# 4   57    0   0     120   354    0  ...       163     1      0.6    2    0      2
#
# [5 rows x 13 columns]

# %%
X_train, X_test, y_train ,y_test =train_test_split(x,y,test_size=0.3)

# %%
model= RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred=model.predict(X_test)

# %%
accuracy =accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.8791208791208791

# %%
model1.predict([[41,0,1,130,204,0,0,172,0,1.4,2,0,2]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-93cb4a28cc85> in <module>()
# ----> 1 model1.predict([[41,0,1,130,204,0,0,172,0,1.4,2,0,2]])
#
# NameError: name 'model1' is not defined

# %%
accureses=[]
top_acc=0
for i in range(50):
  X_train ,X_test , y_train ,y_test = train_test_split(x,y,test_size=0.3)
  model1 = RandomForestClassifier()
  model1.fit(X_train,y_train)
  y_pred = model1.predict(X_test)
  accuracy =accuracy_score(y_test,y_pred)
  accureses.append(accuracy)
  if accuracy>top_acc:
    top_acc=accuracy
    with open('heart_attack.pickle','wb') as file:
      pickle.dump(model1,file)
print(top_acc)
print(accureses)
# Out:
# 0.8791208791208791
# ...

# %%
model_test =pickle.load(open('heart_failure.pickle','rb'))

# %%
model_test.predict([[41,0,1,130,204,0,0,172,0,1.4,2,0,2]])
# Out:
# array([1])

# %%
X_train.head()
# Out:
#      age  sex  cp  trtbps  chol  fbs  ...  thalachh  exng  oldpeak  slp  caa  thall
# 62    52    1   3     118   186    0  ...       190     0      0.0    1    0      1
# 214   56    1   0     125   249    1  ...       144     1      1.2    1    1      2
# 65    35    0   0     138   183    0  ...       182     0      1.4    2    0      2
# 34    51    1   3     125   213    0  ...       125     1      1.4    2    1      2
# 121   59    1   0     138   271    0  ...       182     0      0.0    2    0      2
#
# [5 rows x 13 columns]

# %%
accureses=[]
top_acc=0
for i in range(50):
  X_train ,X_test , y_train ,y_test = train_test_split(x,y,test_size=0.3)
  model2 = LogisticRegression()
  model2.fit(X_train,y_train)
  y_pred = model1.predict(X_test)
  accuracy =accuracy_score(y_test,y_pred)
  accureses.append(accuracy)
  if accuracy>top_acc:
    top_acc=accuracy
    with open('heart_failure.pickle','wb') as file:
      pickle.dump(model1,file)
print(top_acc)
print(accureses)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
model_test2 =pickle.load(open('heart_failure.pickle','rb'))

# %%
model_test2.predict([[41,0,1,130,204,0,0,172,0,1.4,2,0,2]])
# Out:
# array([1])
